# %% [markdown]
# # **TASK 4**

# %% [markdown]
# # **STOCK MARKET PREDICTION USING NUMERICAL AND TEXTUAL**

# %% [markdown]
# ### **SUBMITTED BY- VAISHALI SHRIVASTAVA**

# %% [markdown]
# ## **Importing Text Data**

# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-6dcc5e2e-ee06-4dc2-a916-e6f3d072720a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6dcc5e2e-ee06-4dc2-a916-e6f3d072720a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vaishalikumari","key":"26c23d95d6e41554adce31b6bf4e000c"}'}

# %%
 ! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
 ! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                               title                                                 size  lastUpdated          downloadCount
# ----------------------------------------------------------------  --------------------------------------------------  ------  -------------------  -------------
# heeraldedhia/groceries-dataset                                    Groceries dataset                                    257KB  2020-09-17 04:36:08           1021
# andrewmvd/trip-advisor-hotel-reviews                              Trip Advisor Hotel Reviews                             5MB  2020-09-30 08:31:20            560
# balraj98/stanford-background-dataset                              Stanford Background Dataset                           17MB  2020-09-26 12:57:59             83
# nehaprabhavalkar/indian-food-101                                  Indian Food 101                                        7KB  2020-09-30 06:23:43            878
# ...

# %%
# !kaggle datasets download -d therohk/india-headlines-news-dataset -p/content
# Out:
# ...
#  90% 70.0M/77.5M [00:00<00:00, 93.1MB/s]
# 100% 77.5M/77.5M [00:00<00:00, 113MB/s]

# %%
# !unzip \*.zip
# Out:
# Archive:  india-headlines-news-dataset.zip
#   inflating: india-news-headlines.csv

# %% [markdown]
# **Load data as csv**

# %%
import pandas as pd
data = pd.read_csv('india-news-headlines.csv')
data.head()
# Out:
#    publish_date  ...                                      headline_text
# 0      20010101  ...  win over cena satisfying but defeating underta...
# 1      20010102  ...  Status quo will not be disturbed at Ayodhya; s...
# 2      20010102  ...                Fissures in Hurriyat over Pak visit
# 3      20010102  ...              America's unwanted heading for India?
# 4      20010102  ...                 For bigwigs; it is destination Goa
#
# [5 rows x 3 columns]

# %%
type(data.publish_date[0])
# Out:
# numpy.int64

# %% [markdown]
# **Taking data between 2015-2020**

# %%
def change(text):
  text = str(text)
  start4 = int(text[:4])
  if start4 >= 2015:
    return 'take'
  else:
    return 'not_take'

# %%
data['take'] = data['publish_date'].apply(lambda x: change(x))

# %%
data.head()
# Out:
#    publish_date  ...      take
# 0      20010101  ...  not_take
# 1      20010102  ...  not_take
# 2      20010102  ...  not_take
# 3      20010102  ...  not_take
# 4      20010102  ...  not_take
#
# [5 rows x 4 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['take'].value_counts()
# Out:
# not_take    2004367
# take        1292805
# Name: take, dtype: int64

# %%
data = data[data['take'] == 'take']

# %%
data.shape
# Out:
# (1292805, 4)

# %%
data.head()
# Out:
#          publish_date  ...  take
# 2004367      20150101  ...  take
# 2004368      20150101  ...  take
# 2004369      20150101  ...  take
# 2004370      20150101  ...  take
# 2004371      20150101  ...  take
#
# [5 rows x 4 columns]

# %%
data.drop(['take'],axis = 1,inplace = True)

# %%
data.head()
# Out:
#          publish_date  ...                                headline_text
# 2004367      20150101  ...  Breakfast recipe for diabetics: Moong idlis
# 2004368      20150101  ...              Recipe: Delicious coconut balls
# 2004369      20150101  ...                 Cure that dandruff naturally
# 2004370      20150101  ...                 Recipe: Kerala Chicken curry
# 2004371      20150101  ...                         Recipe: Mocha Coffee
#
# [5 rows x 3 columns]

# %%
data.reset_index(inplace = True,drop=True)

# %%
data['publish_date']=pd.to_datetime(data['publish_date'], format='%Y%m%d', errors='ignore') # Changing date format

# %%
data.rename(columns = {'publish_date':'Date'}, inplace = True)   #Changing column name

# %%
data.head()
# Out:
#         Date  ...                                headline_text
# 0 2015-01-01  ...  Breakfast recipe for diabetics: Moong idlis
# 1 2015-01-01  ...              Recipe: Delicious coconut balls
# 2 2015-01-01  ...                 Cure that dandruff naturally
# 3 2015-01-01  ...                 Recipe: Kerala Chicken curry
# 4 2015-01-01  ...                         Recipe: Mocha Coffee
#
# [5 rows x 3 columns]

# %%
data.tail()
# Out:
#               Date  ...                                      headline_text
# 1292800 2020-06-30  ...      why tiktok removed 1 65 crore videos in india
# 1292801 2020-06-30  ...  apurva asrani calls alia bhatts mother soni ra...
# 1292802 2020-06-30  ...  kangana ranaut gets a doll version of herself ...
# 1292803 2020-06-30  ...  meezaan jaffrey reminisces his childhood days ...
# 1292804 2020-06-30  ...  prabhas20 titled as radhe shyam prabhas and po...
#
# [5 rows x 3 columns]

# %%
data=data[data['headline_text'].str.contains("stock")]  # Taking text data of stocks only

# %%
data.head()
# Out:
#            Date  ...                                      headline_text
# 819  2015-01-02  ...    Wasankar's stock deals hint of a cartel at work
# 4472 2015-01-07  ...  Seeking sufficient supply of urea; farm leader...
# 4958 2015-01-08  ...          DVC; Tenughat plants running on low stock
# 7286 2015-01-11  ...  At livestock meet; calves compete under care o...
# 7875 2015-01-12  ...  Supply of essentials hit over unpaid bills; GM...
#
# [5 rows x 3 columns]

# %%
pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 2.8MB/s
# ...

# %%
# Import the libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import re
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer  # Using vander for sentiment analysis of text data

# %% [markdown]
# # **Uploading numerical data**

# %%
# Load the data
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a5f52b1a-a991-47b6-b974-15c4cba1dbf8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5f52b1a-a991-47b6-b974-15c4cba1dbf8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stocks.csv to stocks.csv
# ...

# %%
data2=pd.read_csv('stocks.csv')  # loading data as csv

# %%
data2.head()
# Out:
#          Date          Open          High  ...         Close     Adj Close   Volume
# 0  2015-01-02  27521.279297  27937.470703  ...  27887.900391  27887.900391   7400.0
# 1  2015-01-05  27978.429688  28064.490234  ...  27842.320313  27842.320313   9200.0
# 2  2015-01-06  27694.230469  27698.929688  ...  26987.460938  26987.460938  14100.0
# 3  2015-01-07  26983.429688  27051.599609  ...  26908.820313  26908.820313  12200.0
# 4  2015-01-08  27178.769531  27316.410156  ...  27274.710938  27274.710938   8200.0
#
# [5 rows x 7 columns]

# %%
data2['Date'] = data2['Date'].astype('datetime64[ns]')  # Changing date type from str

# %% [markdown]
# **Merging both data**

# %%
#Merge the data set on the date field
merge_data = data.merge(data2, how='inner', on='Date', left_index = True)
#Show the merged data set
merge_data.head(3)
# Out:
#         Date headline_category  ...     Adj Close   Volume
# 0 2015-01-02       city.nagpur  ...  27887.900391   7400.0
# 3 2015-01-07   city.chandigarh  ...  26908.820313  12200.0
# 4 2015-01-08       city.ranchi  ...  27274.710938   8200.0
#
# [3 rows x 9 columns]

# %%
merge_data.fillna(0, inplace=True)  # Imputing 0 inplace of Nan
merge_data.reset_index(inplace = True,drop=True) #Resting index after merge
merge_data.head()
# Out:
#         Date headline_category  ...     Adj Close   Volume
# 0 2015-01-02       city.nagpur  ...  27887.900391   7400.0
# 1 2015-01-07   city.chandigarh  ...  26908.820313  12200.0
# 2 2015-01-08       city.ranchi  ...  27274.710938   8200.0
# 3 2015-01-12       city.nagpur  ...  27585.269531   7500.0
# 4 2015-01-12           unknown  ...  27585.269531   7500.0
#
# [5 rows x 9 columns]

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
  return  TextBlob(text).sentiment.polarity

# %%
# Create two new columns 'Subjectivity' & 'Polarity'
merge_data['Subjectivity'] =merge_data['headline_text'].apply(getSubjectivity)
merge_data['Polarity'] =merge_data['headline_text'].apply(getPolarity)

# %%
#Create function to get the sentiment scores (using Sentiment Intensity Analyzer)
def getSIA(text):
  sia = SentimentIntensityAnalyzer()
  sentiment = sia.polarity_scores(text)
  return sentiment

# %%
#Get the sentiment scores for each day
compound = []
neg = []
neu = []
pos = []
SIA = 0
for i in range(0, len(merge_data['headline_text'])):
  SIA = getSIA(merge_data['headline_text'][i])
  compound.append(SIA['compound'])
  neg.append(SIA['neg'])
  neu.append(SIA['neu'])
  pos.append(SIA['pos'])

# %%
#Store the sentiment scores in the data frame
merge_data['Compound'] =compound
merge_data['Negative'] =neg
merge_data['Neutral'] =neu
merge_data['Positive'] = pos

# %%
# Create label where '0' indicates negative sentiment,'1' indicates positive sentiment and '2' indicates neutral 
label=[]
for i in merge_data['Compound']:
  if i>0:
    label.append(1)
  elif i<0:
    label.append(0)
  else:
    label.append(2)

# %%
merge_data['Label']=label # Create Label column in merge_data
merge_data['Label'].value_counts()
# Out:
# 2    1398
# 1     717
# 0     691
# Name: Label, dtype: int64

# %%
merge_data.shape
# Out:
# (2806, 16)

# %%
merge_data.head()
# Out:
#         Date headline_category  ... Positive  Label
# 0 2015-01-02       city.nagpur  ...      0.0      2
# 1 2015-01-07   city.chandigarh  ...      0.0      2
# 2 2015-01-08       city.ranchi  ...      0.0      0
# 3 2015-01-12       city.nagpur  ...      0.0      2
# 4 2015-01-12           unknown  ...      0.0      2
#
# [5 rows x 16 columns]

# %%
#Create a list of columns to keep
keep_columns = [ 'Open',  'High', 'Low','Volume', 'Subjectivity', 'Polarity', 'Compound', 'Negative', 'Neutral' ,'Positive','Label']
df = merge_data[keep_columns]
df
# Out:
#               Open          High           Low  ...  Neutral  Positive  Label
# 0     27521.279297  27937.470703  27519.259766  ...    1.000      0.00      2
# 1     26983.429688  27051.599609  26776.119141  ...    1.000      0.00      2
# 2     27178.769531  27316.410156  27101.939453  ...    0.741      0.00      0
# 3     27523.859375  27620.660156  27323.740234  ...    1.000      0.00      2
# 4     27523.859375  27620.660156  27323.740234  ...    1.000      0.00      2
# ...            ...           ...           ...  ...      ...       ...    ...
# 2801  40979.390625  41075.761719  40848.699219  ...    1.000      0.00      2
# 2802  41161.539063  41163.789063  40996.078125  ...    1.000      0.00      2
# 2803  41138.261719  41143.218750  40664.179688  ...    0.690      0.31      1
# 2804  40852.609375  40885.031250  40554.039063  ...    1.000      0.00      2
# 2805  40852.609375  40885.031250  40554.039063  ...    1.000      0.00      2
#
# [2806 rows x 11 columns]

# %%
#Create the feature data set
X = df
X = np.array(X.drop(['Label'],1))
#Create the target data set
y = np.array(df['Label'])

# %%
from sklearn.model_selection import train_test_split

# %%
#Split the data into 80% training and 20% testing data sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
model = LinearDiscriminantAnalysis().fit(x_train, y_train)

# %%
#Get the models predictions/classification
predictions = model.predict(x_test)
predictions
# Out:
# array([2, 0, 2, 1, 1, 2, 2, 2, 2, 2, 0, 1, 1, 2, 0, 1, 2, 2, 2, 1, 2, 2,
#        2, 2, 2, 1, 2, 1, 1, 2, 0, 2, 0, 1, 1, 1, 0, 2, 0, 2, 0, 1, 2, 0,
#        1, 2, 2, 0, 2, 2, 2, 2, 2, 1, 1, 2, 0, 0, 0, 1, 2, 2, 2, 0, 0, 0,
#        2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 1, 2, 2, 1, 1, 0, 2, 2, 2, 2, 2,
#        0, 2, 1, 2, 1, 2, 1, 1, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 1, 0, 0, 1,
#        2, 2, 1, 1, 2, 2, 0, 2, 1, 1, 0, 0, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 1, 0, 2, 1, 2, 2, 0, 0, 0, 2, 2, 0, 0, 2, 2, 2, 0, 0, 2, 2,
#        0, 0, 2, 1, 2, 1, 2, 0, 0, 2, 0, 1, 0, 1, 0, 1, 0, 0, 1, 2, 2, 1,
#        2, 1, 2, 1, 2, 2, 1, 1, 2, 1, 2, 2, 2, 0, 2, 0, 1, 0, 2, 1, 1, 2,
#        2, 2, 2, 2, 1, 2, 0, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 0, 2, 1, 2, 1,
#        0, 0, 2, 2, 2, 2, 2, 1, 0, 0, 2, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1, 2,
#        0, 0, 2, 2, 0, 0, 2, 1, 0, 2, 1, 0, 2, 2, 2, 1, 2, 2, 2, 1, 0, 0,
#        2, 2, 0, 2, 1, 0, 0, 1, 2, 2, 2, 2, 0, 2, 2, 1, 0, 2, 0, 2, 1, 2,
# ...

# %%
from sklearn.metrics import classification_report

# %%
#Show the models metrics
print( classification_report(y_test, predictions) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       132
#            1       1.00      0.92      0.96       142
#            2       0.95      1.00      0.98       288
#
#     accuracy                           0.97       562
#    macro avg       0.98      0.96      0.97       562
# weighted avg       0.97      0.97      0.97       562

# %% [markdown]
# # **THANK YOU**
